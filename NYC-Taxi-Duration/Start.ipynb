# %%
# importing the libraries
import os
import pandas as pd
import matplotlib.pyplot as plt
import operator
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
# %matplotlib inline
# Out:
# /Users/adityaarora/anaconda3/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
Columns = ["vendor_id","passenger_count","pickup_longitude","pickup_latitude","dropoff_longitude","dropoff_latitude","store_and_fwd_flag","day","month","hour","minute","second"]

# %%
def readData(FileName, is_test=False):
    df = pd.read_csv(FileName)
    return df

# %%
def processData(data):
    store_and_fwd_flag = LabelEncoder()
    store_and_fwd_flag.fit(['Y','N'])
    data["store_and_fwd_flag"] = store_and_fwd_flag.transform(data["store_and_fwd_flag"])
    #2016-06-30 23:59:58
    data["day"] = pd.to_datetime(data["pickup_datetime"]).map(lambda x: x.day)
    data["month"] = pd.to_datetime(data["pickup_datetime"]).map(lambda x: x.month)
    data["hour"] = pd.to_datetime(data["pickup_datetime"]).map(lambda x: x.hour)
    data["minute"] = pd.to_datetime(data["pickup_datetime"]).map(lambda x: x.minute)
    data["second"] = pd.to_datetime(data["pickup_datetime"]).map(lambda x: x.second)
    
    return data

# %%
def input_fn(data): 
    Continuous_cols = {k: tf.constant(data[k].values) for k in Columns}
    label = tf.constant(data['trip_duration'].values)
    return dict(Continuous_cols.items()),label

# %%
def test_fn(data):
    Continuous_cols = {k: tf.constant(data[k].values) for k in Columns}
    return Continuous_cols

# %%
def DNN(train_data, test_data):
    features = []
    for c in Columns:
        features.append(tf.contrib.layers.real_valued_column(str(c)))
   
    
    classifier = tf.contrib.learn.DNNClassifier(feature_columns=features,
                                                hidden_units =[10,20,20,10],
                                                n_classes=2)
    
    classifier.fit(input_fn=lambda: input_fn(train_data), steps=500)
    accuracy = classifier.evaluate(input_fn=lambda: input_fn(train_data), steps=10)

    
    return accuracy,list(classifier.predict(input_fn=lambda:test_fn(test_data)))

# %%
tf.set_random_seed(10)
test = readData("test.csv", True)
# print(test_data)
train = readData("train.csv", False)
processData(train)
processData(test)
# Out:
#                id  vendor_id      pickup_datetime  passenger_count  \
# 0       id3004672          1  2016-06-30 23:59:58                1
# 1       id3505355          1  2016-06-30 23:59:53                1
# 2       id1217141          1  2016-06-30 23:59:47                1
# 3       id2150126          2  2016-06-30 23:59:41                1
# 4       id1598245          1  2016-06-30 23:59:33                1
# 5       id0668992          1  2016-06-30 23:59:30                1
# 6       id1765014          1  2016-06-30 23:59:15                1
# 7       id0898117          1  2016-06-30 23:59:09                2
# 8       id3905224          2  2016-06-30 23:58:55                2
# 9       id1543102          2  2016-06-30 23:58:46                1
# 10      id3024712          1  2016-06-30 23:58:32                4
# 11      id3665810          2  2016-06-30 23:58:05                1
# 12      id1836461          1  2016-06-30 23:58:01                1
# ...

# %%
# print(test_data)
accuracy, trip_duration = DNN(train, test)
print("\n\n\n")
for key in sorted(accuracy):
   print("%s: %s" % (key, accuracy[key]*100))

print("\n\n\n")
id = list(test['id'])
index = 0

indexes = test.index.values
with open("kaggle.csv", "w") as f:
    f.write("id,trip_duration\n")
    for index, prediction in zip(indexes, trip_duration):
        f.write("{0},{1}\n".format(index, prediction))
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/tx/6sm3gcjj1pj7y04lpbdycttm0000gn/T/tmpmcdghyv2
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1a1a36b6a0>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/var/folders/tx/6sm3gcjj1pj7y04lpbdycttm0000gn/T/tmpmcdghyv2'}
# ...
